# %% [markdown]
# ### API Web Scraping
# Author: Kiran Kulkarni

# %%
# !pip install requests

# %%
import requests as rq
import json

# %%
url = "https://api.yelp.com/v3/businesses/search"

api_key = "VPg-s9hXINfeBEImmoCzqTDwYKUsdV5gEi4wh_vSAeoe_OTwq53zhK-ZkBQjMDHd0O0AkqM4hHSDJuDY2DI0I8E3STpuYeZ9hqb0x8wPOfI3wsdvRMFOSo-IwbpJXnYx"

headers = { "Authorization": "Bearer " + api_key }

params = {"term": "Pizza", "location": "NYC"}

response = rq.get(url, headers = headers, params = params)

print(response.text)

businesses = response.json()["businesses"]

print(businesses)

for business in businesses:
    print(business["name"])
# Out:
# {"businesses": [{"id": "ysqgdbSrezXgVwER2kQWKA", "alias": "julianas-pizza-brooklyn-5", "name": "Juliana's Pizza", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/clscwgOF9_Ecq-Rwsq7jyQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=FD2XoK_GD3s4xtuvOGb8-g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=FD2XoK_GD3s4xtuvOGb8-g", "review_count": 2166, "categories": [{"alias": "pizza", "title": "Pizza"}], "rating": 4.5, "coordinates": {"latitude": 40.7026153030093, "longitude": -73.9934159993549}, "transactions": [], "price": "$$", "location": {"address1": "19 Old Fulton St", "address2": "", "address3": "", "city": "Brooklyn", "zip_code": "11201", "country": "US", "state": "NY", "display_address": ["19 Old Fulton St", "Brooklyn, NY 11201"]}, "phone": "+17185966700", "display_phone": "(718) 596-6700", "distance": 323.20506308227306}, {"id": "zj8Lq1T8KIC5zwFief15jg", "alias": "prince-street-pizza-new-york-2"
# ...

# %%
# !pip install twilio
# Out:
# ...
#   Created wheel for twilio: filename=twilio-6.35.4-py2.py3-none-any.whl size=1083921 sha256=010f74c8816884d3f0fdacc90bd89f88b8207f8bdc9cc7580798d83226f24114
#   Stored in directory: C:\Users\kiran\AppData\Local\pip\Cache\wheels\43\16\17\cf25bc9362c6319411371068d07cee5611032ba0210423987c
# Successfully built twilio
# ...

# %%
# !pip install beautifulsoup4

# %%
# !pip install pylint

# %%
r = rq.get("http://api.cfl.ca/v1/games/2015?key=T8Mv9BRDdcB7bMQUsQvHqtCGPewH5y8p")

# %%
print(r.url)

print(r.text)
# Out:
# http://api.cfl.ca/v1/games/2015?key=T8Mv9BRDdcB7bMQUsQvHqtCGPewH5y8p
# ...
